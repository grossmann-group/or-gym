# %%
import or_gym
import gym
from gym import spaces
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
env_name = 'InvManagement-v2'
env = or_gym.make(env_name)

# %%
# Run sample episode
env.reset()
while True:
    action = env.sample_action()
    out = env.step(action)
    if out[2]:
        break
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-3-cee5ba0226ce> in <module>
#       3 while True:
#       4     action = env.sample_action()
# ----> 5     out = env.step(action)
#       6     if out[2]:
#       7         break
#
# ~/GitHub/or-gym/or_gym/envs/supply_network/inventory_management.py in step(self, action)
#     450
#     451         # update stae
# --> 452         self._update_state()
#     453
#     454         # set reward (profit from current timestep)
#
# ~/GitHub/or-gym/or_gym/envs/supply_network/inventory_management.py in _update_state(self)
#     334     def _update_state(self):
#     335         # State is a concatenation of demand, inventory, and pipeline at each time step
# --> 336         demand = np.hstack([self.D[d].iloc[self.period] for d in self.retail_links])
#     337         inventory = np.hstack([self.X[n].iloc[self.period] for n in self.main_nodes])
#     338
#
# ~/GitHub/or-gym/or_gym/envs/supply_network/inventory_management.py in <listcomp>(.0)
#     334     def _update_state(self):
#     335         # State is a concatenation of demand, inventory, and pipeline at each time step
# --> 336         demand = np.hstack([self.D[d].iloc[self.period] for d in self.retail_links])
#     337         inventory = np.hstack([self.X[n].iloc[self.period] for n in self.main_nodes])
#     338
#
# ~/anaconda3/envs/or-gym-dev/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~/anaconda3/envs/or-gym-dev/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1494
#    1495             # validate the location
# -> 1496             self._validate_integer(key, axis)
#    1497
#    1498             return self.obj._ixs(key, axis=axis)
#
# ~/anaconda3/envs/or-gym-dev/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1435         len_axis = len(self.obj._get_axis(axis))
#    1436         if key >= len_axis or key < -len_axis:
# -> 1437             raise IndexError("single positional indexer is out-of-bounds")
#    1438
#    1439     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
env.period
# Out:
# 30

# %%
self = env
# State is a concatenation of demand, inventory, and pipeline at each time step
demand = np.hstack([self.D[d].iloc[self.period] for d in self.retail_links])
inventory = np.hstack([self.X[n].iloc[self.period] for n in self.main_nodes])

# Pipeline values won't be of proper dimension if current
# current period < lead time. We need to add 0's as padding.
if self.period == 0:
    _pipeline = [[self.Y[k].iloc[0]]
        for k, v in self.lead_times.items()]
else:
    _pipeline = [self.Y[k].iloc[max(self.period-v,0):self.period].values
        for k, v in self.lead_times.items()]
pipeline = []
for p, v in zip(_pipeline, self.lead_times.values()):
    if v == 0:
        continue
    if len(p) <= v:
        pipe = np.zeros(v)
        pipe[-len(p):] += p
    pipeline.append(pipe)
pipeline = np.hstack(pipeline)
self.state = np.hstack([demand, inventory, pipeline])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-4-4ab2dd32915a> in <module>
#       1 self = env
#       2 # State is a concatenation of demand, inventory, and pipeline at each time step
# ----> 3 demand = np.hstack([self.D[d].iloc[self.period] for d in self.retail_links])
#       4 inventory = np.hstack([self.X[n].iloc[self.period] for n in self.main_nodes])
#       5
#
# <ipython-input-4-4ab2dd32915a> in <listcomp>(.0)
#       1 self = env
#       2 # State is a concatenation of demand, inventory, and pipeline at each time step
# ----> 3 demand = np.hstack([self.D[d].iloc[self.period] for d in self.retail_links])
#       4 inventory = np.hstack([self.X[n].iloc[self.period] for n in self.main_nodes])
#       5
#
# ~/anaconda3/envs/or-gym-dev/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#     877
#     878             maybe_callable = com.apply_if_callable(key, self.obj)
# --> 879             return self._getitem_axis(maybe_callable, axis=axis)
#     880
#     881     def _is_scalar_access(self, key: Tuple):
#
# ~/anaconda3/envs/or-gym-dev/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1494
#    1495             # validate the location
# -> 1496             self._validate_integer(key, axis)
#    1497
#    1498             return self.obj._ixs(key, axis=axis)
#
# ~/anaconda3/envs/or-gym-dev/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_integer(self, key, axis)
#    1435         len_axis = len(self.obj._get_axis(axis))
#    1436         if key >= len_axis or key < -len_axis:
# -> 1437             raise IndexError("single positional indexer is out-of-bounds")
#    1438
#    1439     # -------------------------------------------------------------------
#
# IndexError: single positional indexer is out-of-bounds

# %%
self.D
# Out:
# Retailer     1
# Market       0
# 0         21.0
# 1         21.0
# 2         19.0
# 3         19.0
# 4         32.0
# 5         24.0
# 6         12.0
# 7         19.0
# 8         14.0
# 9         20.0
# 10        17.0
# 11        19.0
# 12        21.0
# 13        29.0
# 14        18.0
# 15        23.0
# 16        22.0
# 17        16.0
# 18        17.0
# 19        21.0
# 20        16.0
# 21        22.0
# 22        19.0
# 23        15.0
# 24        22.0
# 25        15.0
# 26        25.0
# 27        25.0
# 28        23.0
# 29        17.0
